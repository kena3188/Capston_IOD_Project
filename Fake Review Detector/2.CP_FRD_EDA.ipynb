# %% [markdown]
# ## EDA ON THE REVIEW TEXT
#
# We have conducted an in-depth review surrounding the background of the Amazon dataset, and this time the ``review_text`` itself is going to be taken a further look. To aid in our pre-processing, certain columns will be added to understand certain instances the sentences have. Those include the counts of:
# 1. Word
# 2. Characters (with spaces)
# 3. Stopwords
# 4. Punctuations
# 5. Uppercase characters
#
# After the columns are added, necessary ``summary statistics`` will be conducted to get an idea on how the pre-processing will take place.

# %%
#LIBRARIES 
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
from textblob import TextBlob
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import  PorterStemmer 
import string
import re
import warnings
warnings.simplefilter("ignore")

# %%
file_path = r"C:\Data_Science\Mini Project\Capston Project\Capston_IOD_Project\DATABASE files\amazon_reviews_2019.csv"
update_file_path = r"C:\Data_Science\Mini Project\Capston Project\Capston_IOD_Project\DATABASE files\updated_data.csv"
# Try loading the CSV file with a different encoding

try:
    data = pd.read_csv(file_path, encoding='ISO-8859-1')  # or use 'cp1252'
    review_data = pd.read_csv(update_file_path, encoding='ISO-8859-1')  # or use 'cp1252'
    #REMOVE MAX
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', None)
    
except Exception as e:
    print("Error loading file:", e)

# %%
# Download stopwords if not already downloaded
nltk.download('stopwords')

# Data Cleaning
review_data.drop_duplicates(inplace=True)  # Remove duplicate reviews

# Calculate additional metrics
review_data['total_words'] = review_data['review_text'].apply(lambda x: len(x.split()))  # Count total words
review_data['total_characters'] = review_data['review_text'].apply(lambda x: len(x))  # Count total characters
review_data['total_stopwords'] = review_data['review_text'].apply(lambda x: len([word for word in x.split() if word.lower() in stopwords.words('english')]))  # Count stopwords
review_data['total_punctuations'] = review_data['review_text'].apply(lambda x: len([char for char in x if char in '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~']))  # Count punctuations
review_data['total_uppercases'] = review_data['review_text'].apply(lambda x: len([char for char in x if char.isupper()]))  # Count uppercases

# Display the first few rows of the dataset with new columns
print(data.head())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#   report_date online_store           upc retailer_product_code          brand  \
# 0   1/02/2019  FRESHAMAZON  8.720000e+12            B0142CI6FC  Dove Men+Care
# 1   1/03/2019  FRESHAMAZON  5.000000e+12            B014DFNNRY        Marmite
# 2   1/03/2019  FRESHAMAZON  5.000000e+12            B014DFNNRY        Marmite
# 3   1/03/2019  FRESHAMAZON  8.710000e+12            B014DFKELC          Knorr
# 4   1/03/2019  FRESHAMAZON  8.720000e+12            B014G37I7E            Cif
#
#         category sub_category  \
# 0  Personal Care         Deos
# 1          Foods      Savoury
# 2          Foods      Savoury
# 3          Foods      Savoury
# 4       Homecare          HHC
#
#                                  product_description review_date  \
# 0  Dove Men+Care Extra Fresh Anti-perspirant Deod...   1/01/2019
# 1                 Marmite  Spread Yeast Extract 500g   1/02/2019
# 2                 Marmite  Spread Yeast Extract 500g   1/02/2019
# 3                      Knorr  Beef Stock Pot 8 x 28g   1/02/2019
# 4                   Cif Citrus Bathroom Mousse 500ml   1/02/2019
#
#    review_rating                                       review_title  \
# 0              5                             Dove Mens + Deodorant
# 1              5                         Great for a marmite lover!
# 2              4                                       Vitamin B12.
# 3              5  A Very Handy Flavour Top - Up to Keep In The C...
# 4              5                                         Very handy
#
#                                          review_text  is_competitor  \
# 0  As you get older, you know what you like and w...              0
# 1  Three gigantic marmite jars that will last pro...              0
# 2                                          Excellent              0
# 3         A great flavour top - up for slow cooking.              0
# 4                          Does what is says it does              0
#
#       manufacturer market  matched_keywords  time_of_publication  \
# 0  Unilever Global     UK               NaN                  NaN
# 1  Unilever Global     UK               NaN                  NaN
# 2  Unilever Global     UK               NaN                  NaN
# 3  Unilever Global     UK               NaN                  NaN
# 4  Unilever Global     UK               NaN                  NaN
#
#                                                  url review_type  \
# 0  http://www.amazon.co.uk/gp/customer-reviews/RE...     Organic
# 1  http://www.amazon.co.uk/gp/customer-reviews/R1...     Organic
# 2  http://www.amazon.co.uk/gp/customer-reviews/RD...     Organic
# 3  http://www.amazon.co.uk/gp/customer-reviews/R2...     Organic
# 4  http://www.amazon.co.uk/gp/customer-reviews/RJ...     Organic
#
#   parent_review  manufacturers_response dimension1  \
# 0         Child                     NaN       Deos
# 1         Child                     NaN    Savoury
# 2         Child                     NaN    Savoury
# 3        Parent                     NaN    Savoury
# 4        Parent                     NaN        HHC
#
#                                           dimension2  \
# 0                     Male Anti-Perspirant Deodorant
# 1                                 COTC Yeast Extract
# 2                                 COTC Yeast Extract
# 3  Beef Stock/Pots/Cubes/Extract/Liquid/Concentrated
# 4                                    Bathroom Mousse
#
#                             dimension3  dimension4  dimension5  dimension6  \
# 0  COTC Male Anti-Perspirant Deodorant         NaN         NaN         NaN
# 1                   COTC Yeast Extract         NaN         NaN         NaN
# 2                   COTC Yeast Extract         NaN         NaN         NaN
# 3                           Stock Pots         NaN         NaN         NaN
# 4                      Bathroom Mousse         NaN         NaN         NaN
#
#                             dimension7        dimension8  verified_purchase  \
# 0  COTC Male Anti-Perspirant Deodorant  Core of the Core               True
# 1                   COTC Yeast Extract  Core of the Core               True
# 2                   COTC Yeast Extract  Core of the Core               True
# 3                           Stock Pots  Core of the Core               True
# 4                                  NaN  Core of the Core              False
#
#    helpful_review_count                        review_hash_id
# 0                     0  3f129b02-ea76-0323-bd59-235d97a4f83f
# 1                     0  d7f3b9aa-e8b3-626d-683b-374e201c8315
# 2                     0  e58a523d-0155-a366-f107-7ac6817ac3b7
# 3                     0  aaa9bb87-4f99-bb89-65cb-3b400ebb45c0
# 4                     0  48c71b34-d7fe-5e90-51dd-239e153fb0ae

# %%
review_data.head() #UPDATED
# Out:
#    Unnamed: 0  review_rating  \
# 0           0              5
# 1           1              5
# 2           2              4
# 3           3              5
# 4           4              5
#
#                                          review_text  verified_purchase  \
# 0  As you get older, you know what you like and w...               True
# 1  Three gigantic marmite jars that will last pro...               True
# 2                                          Excellent               True
# 3         A great flavour top - up for slow cooking.               True
# 4                          Does what is says it does              False
#
#    total_words  total_characters  total_stopwords  total_punctuations  \
# 0           39               202               19                   7
# 1           30               175                9                   6
# 2            1                 9                0                   0
# 3            9                42                3                   2
# 4            6                25                5                   0
#
#    total_uppercases
# 0                 5
# 1                 4
# 2                 1
# 3                 1
# 4                 1

# %%
#DROPPING UNWANTED COLUMN
review_data.drop(['Unnamed: 0'], axis=1, inplace=True)

# %% [markdown]
# ### Summary Statistics

# %%
review_data.describe()
# Out:
#        review_rating  total_words  total_characters  total_stopwords  \
# count    1718.000000  1718.000000       1718.000000      1718.000000
# mean        4.441793    33.199069        177.890570        15.210710
# std         1.123083    35.258955        189.818467        17.383135
# min         1.000000     1.000000          2.000000         0.000000
# 25%         4.000000     7.000000         41.000000         2.000000
# 50%         5.000000    21.000000        114.500000         9.000000
# 75%         5.000000    50.000000        268.750000        24.000000
# max         5.000000   287.000000       1624.000000       138.000000
#
#        total_punctuations  total_uppercases
# count         1718.000000       1718.000000
# mean             4.434226          3.841676
# std              5.177685          4.319838
# min              0.000000          0.000000
# 25%              1.000000          1.000000
# 50%              3.000000          3.000000
# 75%              7.000000          5.000000
# max             42.000000         54.000000

# %% [markdown]
# > Readings
# 1. The mean characters within the entire dataset happens to be at 177, averaging at about 33 words per review.
# 2. On average, there are about 9 stop words, and within the sentences there are about 4 punctuations.
# 3. As for the uppercase letters, from the mean value it is safe to assume that most of the reviews utlized their uppercases as Sentence Case.

# %%
review_data.groupby("verified_purchase").describe().T
# Out:
# verified_purchase               False        True
# review_rating      count   900.000000   818.000000
#                    mean      4.315556     4.580685
#                    std       1.187805     1.030249
#                    min       1.000000     1.000000
#                    25%       4.000000     5.000000
#                    50%       5.000000     5.000000
#                    75%       5.000000     5.000000
#                    max       5.000000     5.000000
# total_words        count   900.000000   818.000000
#                    mean     50.273333    14.413203
#                    std      36.865217    21.041613
#                    min       1.000000     1.000000
#                    25%      23.000000     3.000000
#                    50%      48.000000     8.000000
#                    75%      63.000000    17.000000
#                    max     282.000000   287.000000
# total_characters   count   900.000000   818.000000
#                    mean    268.920000    77.735941
#                    std     199.070130   113.775095
#                    min       4.000000     2.000000
#                    25%     126.000000    18.000000
#                    50%     247.000000    44.500000
#                    75%     335.000000    90.750000
#                    max    1541.000000  1624.000000
# total_stopwords    count   900.000000   818.000000
#                    mean     23.515556     6.073350
#                    std      18.337850    10.268703
#                    min       0.000000     0.000000
#                    25%      10.000000     1.000000
#                    50%      21.000000     3.000000
#                    75%      31.000000     7.000000
#                    max     138.000000   136.000000
# total_punctuations count   900.000000   818.000000
#                    mean      6.837778     1.789731
#                    std       5.607709     2.893422
#                    min       0.000000     0.000000
#                    25%       3.000000     0.000000
#                    50%       6.000000     1.000000
#                    75%       9.000000     3.000000
#                    max      42.000000    28.000000
# total_uppercases   count   900.000000   818.000000
#                    mean      5.245556     2.297066
#                    std       4.548433     3.448664
#                    min       0.000000     0.000000
#                    25%       2.000000     1.000000
#                    50%       4.500000     1.000000
#                    75%       7.000000     3.000000
#                    max      54.000000    52.000000

# %% [markdown]
# > Findings
# 1. Review Length: False reviews are longer, averaging 50 words and 268 characters, while True reviews average 14 words and 77 characters.
# 2. Stopwords Usage: False reviews contain more stopwords, indicating possible filler content.
# 3. Punctuation and Case: False reviews have more punctuations and uppercase characters, suggesting they use longer, more complex sentences compared to True reviews.

# %%
# Heatmap for Correlation Matrix
plt.figure(figsize=(10, 8))

# Calculate the correlation matrix for the specified columns
correlation_matrix = review_data[['review_rating', 'total_words', 'total_stopwords']].corr()

# Create the heatmap
sns.heatmap(correlation_matrix, 
            annot=True,                   # Annotate cells with correlation values
            cmap='coolwarm',              # Color map for the heatmap
            fmt='.2f',                    # Format for the annotation text
            square=True,                  # Make cells square-shaped
            linewidths=.5,                # Add lines between cells
            cbar_kws={"shrink": .8})      # Adjust color bar size

# Title and labels
plt.title('Correlation Heatmap: Review Ratings, Total Words, and Total Stopwords', fontsize=18)
plt.xlabel('Variables', fontsize=14)
plt.ylabel('Variables', fontsize=14)

# Display the plot
plt.show()

# %%
colors = ['#4c72b0', '#55a868']

# %%
# Step 4: Visualizing the distribution of helpful review counts
plt.figure(figsize=(10, 5))
sns.histplot(data['helpful_review_count'], bins=20, kde=True, color='teal')
plt.title('Distribution of Helpful Review Counts')
plt.xlabel('Helpful Review Count')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# > In a typical scenario, the helpful_review_count column helps determine which reviews assist users in making purchase decisions. However, in this dataset, most reviews show a count of zero, with only a few having minimal values. This lack of useful data could skew our ability to identify fake versus genuine reviews. To mitigate bias in our model building, we will exclude this column from our analysis.

# %%
sns.set(style="whitegrid")
sns.catplot(x='category', kind='count', hue='verified_purchase', palette='viridis', data=data)
plt.xlabel("category")
plt.ylabel("count of reviews")
plt.title("Count of Product Categories")
# Out:
# Text(0.5, 1.0, 'Count of Product Categories')

# %%
# Set the figure size
fig, axes = plt.subplots(1, 2, figsize=(16, 8))  # 1 row, 2 columns

# Boxen Plot for Total Words by Review Rating
sns.boxenplot(x='review_rating', y='total_words', data=review_data, palette=colors, ax=axes[0])
axes[0].set_title('Boxen Plot of Total Words by Review Rating', fontsize=18)
axes[0].set_xlabel('Review Rating', fontsize=14)
axes[0].set_ylabel('Total Words', fontsize=14)
axes[0].tick_params(axis='both', labelsize=12)
axes[0].grid(axis='y')

# Boxen Plot for Total Stopwords by Review Rating
sns.boxenplot(x='review_rating', y='total_stopwords', data=review_data, palette=colors, ax=axes[1])
axes[1].set_title('Boxen Plot of Total Stopwords by Review Rating', fontsize=18)
axes[1].set_xlabel('Review Rating', fontsize=14)
axes[1].set_ylabel('Total Stopwords', fontsize=14)
axes[1].tick_params(axis='both', labelsize=12)
axes[1].grid(axis='y')

# Adjust layout
plt.tight_layout(pad=5)
plt.show()

# %%
# Create a count plot for product sub-categories, grouped by verified purchases
sns.catplot(y='sub_category', kind="count", hue="verified_purchase", data=data, palette=colors, height=5, aspect=3)

# Set labels and title
plt.ylabel("Product Sub Category")
plt.xlabel("Count of Reviews")
plt.title("Count of Product Sub Categories by Verified and Non-Verified Reviews")

# Show the plot
plt.show()

# %% [markdown]
# > Looking further into the categories, we can see that the sub-categories with more unverified reviews are under skin care, skin cleansing, personal care and dressings. Most of them are under the Personal care category, with exception to dressings, which falls under the Foods section.
#
# > Laundry happens to be the place with the most number of purchases and the highest number of verified purchases, which adds up to the graph above where this sub-cateogory falls under the Home care category.

# %%
print(data['verified_purchase'].unique())
# Out:
# [ True False]

# %%
colors = ['#4c72b0', '#55a868']
plt.figure(figsize=(10, 4)); 
for i, (df, title) in enumerate(zip([data, review_data], ['Before Dropping Duplicates', 'After Dropping Duplicates'])): 
    plt.subplot(1, 2, i + 1); 
    plt.pie(df['verified_purchase'].value_counts().reindex([True, False]).fillna(0).values, 
            colors=colors, 
            labels=df['verified_purchase'].value_counts().reindex([True, False]).fillna(0).index.astype(str), 
            autopct='%1.1f%%', 
            startangle=90); 
    plt.title(f'True and False Reviews Count ({title})'); 
plt.tight_layout(); plt.show()

# %% [markdown]
# > The Verified Purchases (VP) column serves as the target variable, showing a nearly balanced distribution of true (56%) and false (44%) reviews. Amazon's VP feature combats fake reviews by requiring purchase confirmation, enhancing feedback credibility from genuine buyers.
#
# >After removing duplicates, the distribution reflects  of True (47%) and  False (52%) reviews, indicating a slight increase in the number of False values while still maintaining a balanced dataset.

# %%
# EDA: Distribution of Review Ratings
#  Set figure size
plt.figure(figsize=(13, 4))

# Loop through datasets and titles
for i, (df, title) in enumerate(zip([data, review_data], ['Before Dropping Duplicates', 'After Dropping Duplicates'])):
    plt.subplot(1, 2, i + 1)  # Create a subplot
    sns.countplot(x='review_rating', hue='verified_purchase', data=df, palette=colors)  # Create the count plot
    plt.xlabel("Review Rating")  # Set x-axis label
    plt.ylabel("Count of Reviews")  # Set y-axis label
    plt.title(f"Distribution of Review Ratings by Verified Purchase ({title})")  # Set title

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# > The analysis reveals that while removing duplicates significantly reduces total review counts, the distribution between true and false reviews remains consistent, with the 5-star rating continuing to dominate.

# %% [markdown]
# ### REVIEW TEXT EDA

# %%
# Select relevant columns
cols = ["verified_purchase", "review_text"]
vprt = review_data[cols]  # Making a subset of the DataFrame

# Filtering based on True and False VP
checkTrue = vprt["verified_purchase"] == True
filtered_true = vprt[checkTrue]

checkFalse = vprt["verified_purchase"] == False
filtered_false = vprt[checkFalse]

# Average review length based on True and False VP
false_average_length = filtered_false["review_text"].apply(len).mean()
true_average_length = filtered_true["review_text"].apply(len).mean()

# Prepare data for plotting
x = [true_average_length, false_average_length]
y = ["True", "False"]

# Plotting the graph
sns.barplot(x=x, y=y, palette=colors)
plt.xlabel("Average Length of Reviews")
plt.ylabel("Verified Purchases")
plt.title("Average Length of Reviews Based on Verified Purchases")
plt.show()

# %% [markdown]
# >The graph reveals that the average length of reviews marked as false (unverified purchases) exceeds that of verified reviews. Specifically, false reviews average over 250 characters, while verified reviews typically range between 50 and 100 characters.
#
# >This finding aligns with observations from platforms specializing in identifying fraudulent reviews, which suggest that fake reviews often have longer lengths compared to legitimate ones. The longer average length of false reviews may indicate an attempt to appear more detailed or convincing, even when the reviewer lacks genuine experience with the product.

# %% [markdown]
# ## PRE-PROCESSING
#
# Text preprocessing is essential for cleaning text data and making it suitable for model training. Text data often contains noise, such as emotions, punctuation, and varying cases, which complicates analysis. Since machines process numbers rather than words, efficient conversion of text to numerical format is necessary.
#
# ## Summary of Noise in Review Text
# The summary statistics reveal occurrences of the aforementioned noise within the review text, prompting the need for thorough preprocessing.
#
# > To Do
# 1. Drop unwanted columns:Eliminate any irrelevant features that do not contribute to the analysis.
# 2. Lowercasing:Convert all text to lowercase to maintain uniformity and avoid case sensitivity issues.
# 3. Remove Stopwords:Eliminate common words (e.g., "and," "the") that do not add significant meaning to the reviews.
# 4. Remove Punctuations and Special charas: Clean the text by removing punctuation marks and special characters to focus on the actual words.
# 5. Stemming: Reduce words to their base or root form to standardize variations (e.g., "running" to "run").

# %%
# #DROP UNNECESSARY COLUMNS
# review_data.drop(["total words","total characters",
#          "total stopwords","total punctuations",
#          "total uppercases","review_rating"], axis=1, inplace=True)
review_data.head()
# Out:
#    review_rating                                        review_text  \
# 0              5  As you get older, you know what you like and w...
# 1              5  Three gigantic marmite jars that will last pro...
# 2              4                                          Excellent
# 3              5         A great flavour top - up for slow cooking.
# 4              5                          Does what is says it does
#
#    verified_purchase
# 0               True
# 1               True
# 2               True
# 3               True
# 4              False

# %% [markdown]
# For now, we are going to be only utlizing review_text and verified_purchase for our classifiers.

# %%
#CORRECT SPELLING
review_data.review_text.apply(lambda i: ''.join(TextBlob(i).correct()))

# %%
#REMOVING THE STOPWORDS,PUNCTUATIONS, LOWERCASING, AND STEMMING OF THE SENTENCES
def text_preprocessing(text):
    removed_special_characters = re.sub("[^a-zA-Z]", " ", str(text))
    tokens = removed_special_characters.lower().split()
    
    stemmer = PorterStemmer()
    cleaned = []
    stemmed = []
    
    for token in tokens:
        if token not in sw:
            cleaned.append(token)
            
    for token in cleaned:
        token = stemmer.stem(token)
        stemmed.append(token)

    return " ".join(stemmed)

# %%
review_data['review_text'] = review_data['review_text'].apply(text_preprocessing)

# %%
review_data['review_text']
# Out:
# 0       get older know like suitabl bodi like dove pro...
# 1       three gigant marmit jar last probabl whole lif...
# 2                                                   excel
# 3                             great flavour top slow cook
# 4                                                     say
# 5                                     excel item good men
# 6                                             thank happi
# 7                                                  beauti
# 8                                     alway buy big bottl
# 9       alway use product heavili mistreat hair work w...
# 10                                             great valu
# 11      one pictur get star regular one use awesom peo...
# 12      item describ excel qualiti rapid deliveri grea...
# 13                            good bodi wash strong smell
# 14                                                  great
# 15                                                  worth
# 16      rememb tri friend hous year ago ive use month ...
# 17                                                  great
# 18      best antiperspir unless like go work snow drif...
# 19                                           love product
# 20                die eat one u die content man love u em
# 21      love rang bodi lotion u greasi easi appli soak...
# 22      suffer dri sensit skin vaselin one product mak...
# 23      absolut love stuff leav love linger fragranc s...
# 24                                                  happi
# 25      love wash cashmer sweater home save lot money ...
# 26      prior receiv pretti rough elbow particular ski...
# 27                                             happi item
# 28      realli like textur almost like gel realli ligh...
# 29                                             smell nice
# 30      great deal tresem shampoo give long last suppl...
# 31                                             great valu
# 32                                           love comfort
# 33                                                horribl
# 34                                              great buy
# 35      love contain easi pour refil nother automat li...
# 36                                        wash shark well
# 37                                                  excel
# 38           good pleasant smell deoder boy love christma
# 39      deliv quickli decent shampoo star one bottl le...
# 40      use lot make brand past bought expens make rem...
# 41                    sure big jar cost doubl size though
# 42      got offer cloth come soft smell great last lon...
# 43      amaz buy last month smelt amaz neighbour even ...
# 44                                great buy smell gorgeou
# 45                            textur like use bath shower
# 46                                           share famili
# 47                                  love even better deal
# 48                                          great product
# 49      bought item give gift advertis dove moisturis ...
# 50      good price nice smell overpow leav white powde...
# 51                                     good wipe good buy
# 52                          nice fragranc seem last cloth
# 53      use tresemm product year previous regular heat...
# 54                           much cheaper boot great valu
# 55                 like blue version overpow aw smell bin
# 56      like use one regular wash everyth come clean u...
# 57                                   excel valu hav carri
# 58                                                   wash
# 59                                       love fresh smell
# 60                                             great item
# 61                         like noodl tast like spare rib
# 62      good deodor easili irrit skin like dove soap s...
# 63                    great bodi wash cheap fast deliveri
# 64      yet tri tast day age start produc perfect glas...
# 65      even worth one star bring lot white stuff high...
# 66                                        bought step dad
# 67         love oh smell good hate year still everyon els
# 68                                             great gift
# 69      classic know hellman mayo cap stay much cleane...
# 70                                                   cool
# 71      absolut great moistur dri skin complain smell ...
# 72                                       great packag buy
# 73                                  work well truli invis
# 74                                       nice cost effect
# 75                                                  great
# 76      exactli say kitchen sink alway get block sinc ...
# 77      favourit scent intens rang smell love last age...
# 78      find best laundri part includ use one dose lik...
# 79                              calori realli big portion
# 80      cream easi appli feel extremli cool doesnt dri...
# 81      execel product made skin feel silki smooth ext...
# 82      cream light odourless leav skin feel genuin sm...
# 83                           fresh clean reliabl deliveri
# 84               great combin start use yo born still use
# 85                               nice fresh smell product
# 86      crave thing transport us back innoc time bovri...
# 87                       love bought cheaper home bargain
# 88      item damag unabl pour without spillag transfer...
# 89                                             good price
# 90                                              came fast
# 91      hi simpl absolut must facial moisturis cannot ...
# 92      pleas go back old capsul new one make househol...
# 93      never usual use laundri soften pleasantli surp...
# 94      marmit lover switch back glass jar marmit righ...
# 95                                                  great
# 96                                                  thank
# 97      got great buy put much wash clean cloth end fr...
# 98      lure entic fragranc condition notic eye would ...
# 99      give good result fragranc strong though last l...
# 100                                                  good
# 101                                       good size spray
# 102     price bulk pack less buy item individu somewhe...
# 103                  like make soup casserol product well
# 104                                   best ice cream ever
# 105     live extrem hard water area half year soon hai...
# 106     easi use recommend want get glam go somewher p...
# 107             disappoint show big condition small arriv
# 108                                             know work
# 109     clean cloth well mani cloth smell good wise pr...
# 110                             would recommend good valu
# 111                                             buy thank
# 112                                                   say
# 113     alway fan dove product antiperspir effect last...
# 114                                 expect repeat purchas
# 115                                      excel valu money
# 116                                 excel clean good valu
# 117                                                 happi
# 118                                            excel valu
# 119                                    great valu shampoo
# 120      exactli wat say box amazon deal less money spent
# 121     exact similar litr one costco thick smelt love...
# 122                               amaz offer price resist
# 123     hand realli dri bleed due eczema handwash dose...
# 124                                              issu say
# 125                        need say use time soup risotto
# 126     simpli love deodrant scent great fresh sporti ...
# 127          thicken gravi realli well add wonder flavour
# 128                                      amaz great price
# 129                      smell great easi one hand applic
# 130                             good valu would recommend
# 131               bodi deodor love smell great valu money
# 132     floor cleaner use smell good home feel refresh...
# 133                                         btilliant buy
# 134                                            valu money
# 135       fabric condition work less one smell divin last
# 136     find shop bought line thought fake brand smell...
# 137     use year happi last can nozzl block within wee...
# 138     buy year content good howev bottl aw three tim...
# 139     pleasant use littl scent want shower gel brill...
# 140     wipe great get stubborn make love fact wipe in...
# 141     great qualiti wipe strong use tear apart like ...
# 142     love face wipe great job remov make left skin ...
# 143     sensit skin work realli well took make easili ...
# 144     use month realli pleas work get make easili sm...
# 145     tri test skin quench night cream light soft te...
# 146     happi product light skin sensit would recommen...
# 147     great water base moisturis light skin give dew...
# 148        anoth great product simpl ever stop make pleas
# 149                                           good flavor
# 150                                                 great
# 151                                    question say bottl
# 152                          good valu favourit condition
# 153                                            love smell
# 154     love product howev hard spray would recommend ...
# 155     got tri wasnt disappoint littl less thick cond...
# 156                                    littl goe long way
# 157     convinc smell match origin seem less thick pre...
# 158     great soap wife love actual moistur skin every...
# 159     love soap clean well keep hand moist good peop...
# 160     definit worth money laundri often last month d...
# 161     arriv super fast two good size bottl dont know...
# 162                                   great product happi
# 163     great price purchas still price would subscrib...
# 164     love smell pour smaller bottl make use manag beat
# 165         pod work well use great valu three bag bought
# 166     love comfort pure children sensit skin irrit l...
# 167                                                 thank
# 168                                            bit wateri
# 169                                                  good
# 170     blue bottl alot better smell less blue bottl c...
# 171     great valu money smell nice seem stop hair sta...
# 172                                          good product
# 173              product arriv broken spilt insid envelop
# 174                                           squirt well
# 175         good valu amount capsul get packet good price
# 176                             bit runni thick liquid ok
# 177                                            work great
# 178     use simpl rich moisturis year need find altern...
# 179                                      excel valu money
# 180                                             great buy
# 181                                 person tast sold mine
# 182                                    three flavour good
# 183     tri mani english mustard time alway come back ...
# 184     titl suggest realli wont buy tea bag pg tip go...
# 185                          bleach bleachi bleach bleach
# 186     buy shampoo husband shave head everi week year...
# 187     dove deodor stick best deodor ever use goe lov...
# 188                                         great qualiti
# 189                        buy amazon prime order problem
# 190                     great product love scent last age
# 191
# 192                                       wash cloth nice
# 193     great tast add depth flavour meal importantli ...
# 194     year ago use love pot noodl student yuck add a...
# 195     like product bottl unsuit plastic thin good th...
# 196     love lynx product happi buy write review femal...
# 197                                               perfect
# 198                             great product great price
# 199     last forev work well chang anoth brand smell p...
# 200                                                   goo
# 201     consider friend brought dinner parti vegan enj...
# 202     product fine struggl get smooth thin lid time ...
# 203     alway buy product love qualiti product smell n...
# 204                        love product keep hair protect
# 205                                            happi item
# 206              brilliant product left drain clear clean
# 207                                            great valu
# 208                                                  fine
# 209     v bought load offer use wash half cap small mu...
# 210     bulk bought drive heavi carri supermarket scen...
# 211     quit solid product find easier use contain pla...
# 212                                    good alround thank
# 213     pouch arriv persil box brown box safe packag g...
# 214           fantast price mother law love great product
# 215                                            well worth
# 216     seem genuin brand came product smell liquid us...
# 217                                       idea claim wash
# 218                                          like product
# 219                                   get live dead handi
# 220                                            love smell
# 221                                     smell good expens
# 222                                                  good
# 223     love use past coupl year recent bought amazon ...
# 224                                       good valu money
# 225          know anyon like smell tast like weed vinegar
# 226     struggl open lid spill everi time tri use cap ...
# 227     use mani year problem differ product itch boug...
# 228     bought week ago tri mani differ tan product be...
# 229     good valu money contain make difficult pour wi...
# 230     never buy capsul stuck togeth leak make unus c...
# 231                    good clean product kid sensit skin
# 232                             nice mustard smooth tasti
# 233                                                 great
# 234                   price rate nephew want christma use
# 235     your look super moistur bodi wash leav skin su...
# 236     love bodi skin get super dri winter product he...
# 237     use kid sensit skin doesnt irrit us great last...
# 238     bodi wash soft origin dove origin smell love p...
# 239     use winter help keep skin moistur find need fo...
# 240     feel like im realli get clean love lotion feel...
# 241     love soft skin feel use product cold winter mo...
# 242                                                  good
# 243     huge bottl smell love cloth dri indoor didnt n...
# 244     buy frequent leav slime cloth particularli low...
# 245                         great smell clean brilliantli
# 246     packag comfort spilt time put wash machin heav...
# 247                                           great price
# 248      love size bottl smell gorgeou littl goe long way
# 249                                      fab stock filler
# 250     great buy use blow dri hair prevent heat damag...
# 251     happi yet prob fault get spray gun work star c...
# 252     condition good howev bottl lid terribl difficu...
# 253                                           cannot beat
# 254                                           never chang
# 255            amazinng smell skin look realli health use
# 256                                             mayb mani
# 257                                         perfect price
# 258             arriv broken lid leak box half bottl left
# 259     good valu set took star expect comfort size pe...
# 260      stock save money quit strong smell need use much
# 261     love creami soap would use anyth els love lath...
# 262                                                  good
# 263          nice smell great anitipersperi also work men
# 264     love product work realli well protect hair wou...
# 265                                                  good
# 266     make hair smell great definit recommend produc...
# 267                                amaz came perfect time
# 268     alway take badeda go holiday love bath sooth s...
# 269     sorri say tast aw creat greasi film top stain ...
# 270                           go laundri deterg work even
# 271                                nice smell last longer
# 272                                            love smell
# 273                               met usual lynx standard
# 274                                  love scent good wash
# 275                                                 excel
# 276                          cream burn skin lot spot buy
# 277     never use anyth els soft creami pamper ideal s...
# 278     bought product mani time best eye cream around...
# 279     love scent smell somewhat like babi powder fem...
# 280          perfect quick snack brilliant cupboard stock
# 281     love soap leav skin feel smooth moisturis use ...
# 282                                    smell realli fresh
# 283     sign subscript great valu wonder smell last ag...
# 284                                            great valu
# 285          smell nice creami textur doeant dri hand buy
# 286     use product liter year chang someth irrit skin...
# 287     smell divin easi use glide skin skin feel soft...
# 288     smell aaaaaaaaamaz fresh great valu larg bottl...
# 289                                                 brill
# 290                                 nice smell shower gel
# 291               love decent fabric soften nice fragranc
# 292                            smell nice cloth nice soft
# 293     love smell comfort buy time would diffid recom...
# 294                                            smell amaz
# 295                     smell nice keep cloth smell fresh
# 296         smell good last long time order anoth product
# 297                                cheaper get ask attend
# 298     usual purchas costco extrem good valu would de...
# 299               may well use plain water would job noth
# 300                                       perfect flavour
# 301                                                    ok
# 302                                               laundri
# 303                                                  nice
# 304                                            great valu
# 305               decent price lot cheaper store last age
# 306                                       nice prefer buy
# 307                                 great hair straighten
# 308                             great product great price
# 309                                                suppos
# 310                                   arriv pot noodl say
# 311     recommend amount refresh fabric similar amount...
# 312                                 smell nice justv hour
# 313              happi product lt concentr say wash state
# 314           dri skin keep moisturis much longer product
# 315               like fabric soften tri other return one
# 316     gave one jar away gift still two huge jar marm...
# 317     smell divin love fresh fragranc last thought d...
# 318                              good price good wash pod
# 319     found cream absorb non greasi oili skin felt c...
# 320                bottl stuff amaz hair recommend enough
# 321     bought treat children love tasti also fill tre...
# 322                        happen love cream eyemak remov
# 323     sceptic use soap u littl miracl first use face...
# 324     tri simpl hydrat cleans wipe even remov makeup...
# 325     recent true soon wipe fantast give skin perfec...
# 326     pleas pleas magnum tub incas chocol amazebal l...
# 327     shower gel mild yet give nice shower experi fe...
# 328     skin quit sensit bodi wash often break use gel...
# 329     tri product first time today packag good easi ...
# 330     artif perfum colour harsh chemic upset skin lo...
# 331     love simpl product shower gel make skin feel c...
# 332     u use shower gel realli like pretti much unsce...
# 333     love nice appli spong shower good make skin wa...
# 334     got coupl day ago use shower refresh leav bodi...
# 335     product leav love fragranc laundri howev hate ...
# 336     pour cap white gold one wash machin expect spr...
# 337     sainsburi cheddar chees sauc mix g scrummi goo...
# 338     realli enjoy luxuri shower gel simpl felt skin...
# 339     perfect sensit skin shower gel cleans refresh ...
# 340     love shower gel exactli aim lather well smell ...
# 341     great shower wash even though cucumb extract s...
# 342     got littl concern detest cucumb wari product w...
# 343     love smell shower gel smell quit natur like br...
# 344     u use around week u say u pretti standard show...
# 345     simpl refresh shower gel realli great sensit s...
# 346     use simpl product rang pretti sensit skin love...
# 347     use shower gel morn say refresh product left s...
# 348     bought month ago cant stop purchas u refresh u...
# 349     love simpl shower gel like gel like glue hard ...
# 350     like simpl brand feel natur chemic bodi wash s...
# 351     neutral product u cheap get pay smell niceish ...
# 352     reactiv skin eczema found shower gel calm aggr...
# 353     amaz product skin feel super soft touch foam e...
# 354     expect simpl product nice gentl skin dont need...
# 355     simpl great ever alway great fan simpl quit se...
# 356     realli gentl cleans strong smell though kind s...
# 357     use week say great product subtl smell clean w...
# 358     love shower gel fresh scent littl bit goe long...
# 359     use simpl brand skin break easili get dri bran...
# 360     bought shower gel time whenev skin sensit reac...
# 361     skin alway feel dri shower howev sinc use prod...
# 362     love simpl product know harm skin start use fa...
# 363     simpl rang full nasti kind skin shower gel ref...
# 364     thought would give shower gel whirl alway look...
# 365     tend use anoth soap free brand end tri u great...
# 366     love shower gel perfum thing especi due babi n...
# 367     u irrit skin instead felt nice soft instantli ...
# 368                                               perfect
# 369                                   spill everywher box
# 370     absolut love scent make cloth smell fresh well...
# 371     pick rush store pleas remov make eas leav skin...
# 372     usual buy organ cosmet want natur product with...
# 373     mayonnais would get star tast contain style su...
# 374     ice cream great cooki dough piec right size ic...
# 375                                 nightli treat perfect
# 376                             perfect even better offer
# 377     far concern best remov makeup even waterproof ...
# 378     tri alot bleach toilet clean product year keep...
# 379     ive tri mani altern mayo beat homemad reliabl ...
# 380                                        half bag split
# 381           good valu money wash realli well love smell
# 382     love rang bodi lotion greasi easi appli soak q...
# 383     happi vaselin intens care cream gentl sooth sk...
# 384     morn receiv bottl vaselin alo sooth tryit samp...
# 385     suffer dri skin age alway look find best produ...
# 386     cream one best bodi cream tri expect much plea...
# 387     decent everyday lotion clean light scent luxur...
# 388           love day cream make skin feel love help age
# 389                great product arriv quickli nice scent
# 390     arriv time well packag great product need much...
# 391        realli good valu money perfect wash babi cloth
# 392                            product leak order suggest
# 393                                       love smell soft
# 394     excel product use awhil suitabl whole famili m...
# 395     start use could find old simpl night cream imp...
# 396     love sweet smell bodi lotion cream thick absor...
# 397     use bodi lotion never tri vaselin one wish ple...
# 398     got coupl day ago use shower smell realli nice...
# 399     lightli fragranc lotion dispens easili bottl f...
# 400     use month love product dri skin use twice week...
# 401     suffer bad dri skin winter start use vaselin i...
# 402     love cream heavi overli soak skin keep moistur...
# 403     winter left dri skin especi hand wrist perfect...
# 404     suffer dri sensit skin vaselin product one moi...
# 405     love light none sticki moisturis goe well soak...
# 406     usual use get big carton brainer last month on...
# 407     bargain howev think consist shop one smell nic...
# 408     great valu money fantast product love smell ea...
# 409     like simpl brand product sensit skin need real...
# 410     havent tri hamper im make christma im sure goo...
# 411                    remov stain keep wash great condit
# 412                           beat price smell clean love
# 413     aw buy wipe thick like wet paper towel usual w...
# 414                         smell beauti well worth money
# 415     easi throw drum messi liquid spill wash well n...
# 416     product anyth gentl realli sting eye leav skin...
# 417     given product review think good booster skin l...
# 418     first time use vaselin intens alo bodi lotion ...
# 419     use lotion got bath felt realli luxuri smelt d...
# 420                 great product well packag great price
# 421               excel valu bulk buy save money long run
# 422                                                    ok
# 423     like deodor afford bulk buy obviou choic far m...
# 424                              arriv ok good item thank
# 425     good qualiti condition water leav cloth soft s...
# 426                                         great product
# 427                 great thank came day later smell love
# 428     use mosturi past caus breakout moisturis job h...
# 429     like product make skin soft skin smell fresh g...
# 430     one product think everi household cabinet patc...
# 431     suffer realli dri skin winter month despit put...
# 432     time year skin tend becom dri itchi within day...
# 433     struggl find moisturis last day without get mi...
# 434     tri lotion firstli get enough smell smell clea...
# 435     prior receiv pretti rough elbow particular ski...
# 436                           fast deliveri great product
# 437     reliabl product even cooler wahs an love fragranc
# 438         valu money nice smell daughter love recommend
# 439                        girlfriend pleas still said ok
# 440                                         great product
# 441                  scrumptiou authent pot noodl flavour
# 442     offer half price pleas also like compact bottl...
# 443                                        love ice cream
# 444         love marmit feel like wast lot squeezi format
# 445     husband said sharp begin quit nice got use ass...
# 446     like chocol ice cream howev quit nice end eat ...
# 447     rich full flavour well love famili expens grea...
# 448     one favourit chocol ice cream especi love dark...
# 449                                        smell love job
# 450     subtl prefer love fragranc linger perfum cream...
# 451     great handwash smell delight use put next wash...
# 452                              thick creami smelt fresh
# 453                     frozen pear scent realli pleasant
# 454     sent review gave hubbi tri hubbi realli like c...
# 455     fantast cream skin look feel like sauna outsta...
# 456                                 nightli treat perfect
# 457     might need use tini bit smell littl overpow tb...
# 458     your look super moistur bodi wash leav skin su...
# 459     use kid sensit skin doesnt irrit us great last...
# 460     bodi wash soft origin dove origin smell love p...
# 461     love bodi skin get super dri winter product he...
# 462     use winter help keep skin moistur find need fo...
# 463     use dove deep moistur shave pretti much entir ...
# 464     feel like im realli get clean love lotion feel...
# 465     tri vaselin bodi lotion think favourit one far...
# 466     tri product impress smell nice left skin feel ...
# 467     love soft skin feel use product cold winter mo...
# 468     absolut fantast find skin goe dri winter weath...
# 469     ive use time morn night shower fresh scent lea...
# 470     love product love fresh smell leav sticki resi...
# 471     got week ago use everyday sinc skin feel soft ...
# 472     use day realli like bodi moisturis heavi still...
# 473     nice alo scent smooth nice light absorb skin t...
# 474     realli like seem moisturis better bodi lotion ...
# 475     love product amaz son suffer dri skin especi w...
# 476     use product week given realli bad skin spot pr...
# 477     oili skin find moisturis offer spf protect wit...
# 478     use year work realli well damag cloth left res...
# 479                                                  goof
# 480        actual good practic use pot keep hot easi make
# 481     realli happi good qualiti valu recommend selle...
# 482     larg bottl shampoo improv hair shini clean ter...
# 483     make hair oili ye protect blow dri last long n...
# 484     great valu money good hair type use hous hair ...
# 485                                            nice smell
# 486                                            smell love
# 487                                             good valu
# 488                            good valu pack fast servic
# 489              best deodor brand alway deliv smell amaz
# 490                                       good valu price
# 491                                             good valu
# 492                            great bo beater smell nice
# 493     realli work well pleasant smell stain cloth ex...
# 494                              love comfort smell fresh
# 495     smell gorgeou huge bottl last age bought stock...
# 496                                                  good
# 497                           smell nice soft static free
# 498     like unperfum vital import littl bunni rabbit ...
# 499     smell nice leav cloth smell nice fresh got las...
# 500          smell good keep pit dri go wrong dove deodor
# 501                                                expect
# 502                                            shower gel
# 503                  excel price size especi much mr poor
# 504                          excel valu price fact bought
# 505                             love smell last age cloth
# 506                                                 great
# 507                            great multi pack subscript
# 508                 better half want cheaper bought local
# 509                     say job pleas purchas definit buy
# 510                                           work expect
# 511     hard get hand think got enough small amount ke...
# 512     purchas cheap realli forgotten bad tast like c...
# 513     handi thing keep cupboard perfect quick snack ...
# 514              use marmit sausag instead mustard addict
# 515                              good price fast deliveri
# 516                                 keep home fresh clean
# 517                                                  like
# 518     absolut love comfort creation fabric condition...
# 519     best shampoo ever use make hair shini soft ful...
# 520                               brilliant qualiti price
# 521             absolut love deodor much cheaper buy line
# 522                                     good valu big pot
# 523
# 524     love scent get offer massiv bonu alway leav wa...
# 525     realli pleas condition smell love good offer c...
# 526                      love smell howev bottl half full
# 527                  bought bulk still work way shall buy
# 528     qualiti expect persil pod dissolv properli low...
# 529                                         buy anyth els
# 530                                   keep wash machin go
# 531                                            excel valu
# 532                                                  good
# 533                                               qualiti
# 534     use time alway larg load job smell better othe...
# 535     alway go persil non bio cheap alway leav lumpi...
# 536     read detail correctli small bottl total litr e...
# 537     read post amazon sell wash send larger one dec...
# 538                                      excel valu money
# 539                    brilliant price happi purchas last
# 540                                            wife happi
# 541     got luvli smell save carri home shop much easi...
# 542                          tini littl bottl worth money
# 543     treat much appreci husband current portug miss...
# 544     tan sunb spray tan take skin thought would tri...
# 545                                       effect wash pod
# 546                     perfect persil best fast deluveri
# 547                                    go wrong paid pack
# 548     although great price come sever allergi idea u...
# 549                         smell divin definit recommend
# 550                                     happi worth moeni
# 551     bought save lumber home larg bottl supermarket...
# 552                                     alway use comfort
# 553     know actual comfort pure fabric condition labe...
# 554                               seem product miss bottl
# 555                                                   job
# 556             famili love marshmallow particularli good
# 557     ice cream smooth indulg marshmallow mostli bot...
# 558     whole famili realli enjoy ice cream realli lov...
# 559     ice cream nice differ textur within isnt choco...
# 560     love ice cream nice chunk chocol love flavour ...
# 561                    usual buy mr muscl one ill go back
# 562     great product use first time bath shave leg lo...
# 563     winter realli take toll skin moisturis wonder ...
# 564     tri product total impress soft left skin refre...
# 565     decidedli smaller normal magnum raspberri news...
# 566     gentl love lather keen fragranc would tri othe...
# 567     mani thank ocado free trial product got husban...
# 568     wouldnt normal choos chocol ice cream husband ...
# 569     receiv tub tri dessert sunday lunch one tub su...
# 570             want sweet rich chocol ice cream hit spot
# 571     bought think ordinari simpl cleans wipe packag...
# 572     ms skin get burnt fron bladder weak use oil ge...
# 573                      good product excel everi day use
# 574     shower gel smell nice quit thick runni like ge...
# 575     great product concentr good linger fragranc bo...
# 576     famili love great chocol ice cream kid enjoy f...
# 577                                      everyon love buy
# 578     use moisturis daili year alway great price how...
# 579                      tri product happi make hair soft
# 580     wow love much smell amaz linger skin ive notic...
# 581     would much recommend product use skin feel sof...
# 582     product would bought although like vaselin pro...
# 583     product smell gorgeou use kitchen certainli bu...
# 584     husband use deoder found applic uncomfort arm ...
# 585     pour kitchen sink drain left overnight drainag...
# 586        like chocol icecream good one good textur well
# 587           love creami good chocol flavour contain gmo
# 588     alway use cif thought great product howev micr...
# 589                              chang great option start
# 590     best stock ever unless make gravi richer wonde...
# 591     shame contain palm oil albeit label fat would ...
# 592     husband favorit imposs find previou sourc chec...
# 593     realli impress first time use self tan nervou ...
# 594     love subtl soft colour skin pale use medium da...
# 595     regular user number simpl product impress refr...
# 596     love shower morn moreov use realli fresh showe...
# 597     got product day ago use alreadi mani time migh...
# 598     love simpl rang great sensit skin never tri sh...
# 599     alway use simpl product got notif request prod...
# 600     simpl refresh shower gel person u like daughte...
# 601     realli good shower gel sensit skin u overwhelm...
# 602     like rest simpl rang product realli kind skin ...
# 603     simpl shower gel clear gel lather realli reall...
# 604     alway big fan simpl shower gel never disappoin...
# 605     love shower gel mostli simplic fact contain na...
# 606     shower gel realli simpl use small amount creat...
# 607     got husband chang classic lynx deodor use much...
# 608     skin dri itchi scali matter noth help switch d...
# 609     bodi lotion gener size last long time therefor...
# 610     iv use vaselin intens care alo sooth bodi loti...
# 611                                       work like magic
# 612                great valu money great buy think twice
# 613                                clean hair well though
# 614                                             good valu
# 615                        big bottl low cost let go deep
# 616            thought get bargain found cheaper elsewher
# 617     absolut indistinguish finest dairi vanilla ice...
# 618     like lather nice love subtl fragranc left hand...
# 619     decent size bottl firm lid smell subtl quit ni...
# 620                                            love fresh
# 621                         obvious chocol ice cream like
# 622     realli enjoy creami ice cream plenti chocol fi...
# 623     realli love rich creami ice cream went great k...
# 624     nice flavour although sweet textur seem littl ...
# 625                    good look good price big good size
# 626                                                 snack
# 627                                great valu good servic
# 628                                  brilliant valu money
# 629                                             love love
# 630             like smell lather well littl goe long way
# 631                            long last scent bare sweat
# 632                     larg pack work cheaper shop order
# 633     use deodor last year far best one everi use co...
# 634                                                expect
# 635                                   origin smell teenag
# 636     treat thank ocado send review chocolatey ice c...
# 637     sent product review love new style bottl stand...
# 638                        feel nice hand aroma isnt cloy
# 639                                               conveni
# 640                        alway bulk buy tresmemm amazon
# 641                                     tast horribl hard
# 642             first love left say bigger jar would nice
# 643               littl bit rough know thought would soft
# 644     like awesom long last qualiti smell dove men f...
# 645                           fantast buy speedi deliveri
# 646     great price larg shampoo tresemm good shampoo ...
# 647                 bottl side seal broken leak box stuff
# 648              love smell wash great unfortun agre skin
# 649     spill everywher box pleas tell look like drop ...
# 650        actual good practic use pot keep hot easi make
# 651                         kid love great chocol flavour
# 652     ice cream classic enjoy young children love li...
# 653     probabl least favourit ben jerri ice cream sic...
# 654     great everyday moisturisor skin type quit runn...
# 655                 whenev never contain white chocol one
# 656                                     one mani favourit
# 657     absolut gorgeou rich gooey marshmallowey good ...
# 658     children love flavour think novelti chocol fis...
# 659     hard water problem ad tap water old iron iron ...
# 660     ive use simpl product sensit skin allerg certa...
# 661     happi chose buy incred sooth refresh skin appl...
# 662     realli impress first time use self tan nervou ...
# 663     husband favorit imposs find previou sourc chec...
# 664           cooki dough best ben jerri tasti stop start
# 665          what like creami chocol tast big hunk chocol
# 666     love size magnum much better dessert hous full...
# 667                                             excel buy
# 668                                                 wrong
# 669     liter curri powder anyth noodl besid sachet ba...
# 670                                        like condition
# 671         fast diliveri nice pack make wash fresh clean
# 672                         open liquid came box lid snap
# 673                                             excel buy
# 674     say tasti beef tomato add grate cheddar chees ...
# 675                                    tri yet smell nice
# 676     recent develop eczema first time due allerg re...
# 677     quit enjoy use conceal moment coverag quit lig...
# 678     stone need pot pot help munchi must stone give...
# 679                                             good deal
# 680     sweet small portion make indulg treat pretti m...
# 681     mean guy amaz littl chocci fish secret deposit...
# 682             usual flavour tri chang pleasantli supris
# 683                thoroughli recommend great clean smell
# 684      cheapest found quantiti get hope back offer soon
# 685               deodor ever use done past year straight
# 686     buy year clean hydrat skin notic skin feel nic...
# 687     best makeup wipe ever tri wear quit layer wate...
# 688                                 repair dri end incred
# 689                    exactli would buy shop better valu
# 690     buy year clean hydrat skin notic skin feel nic...
# 691                 kcal definit soup calori control diet
# 692                                      grate valu money
# 693                                 product burst transit
# 694                       leav cloth smell love keep soft
# 695                                             recommend
# 696     autoimmun diseas call dermatomyos caus dri itc...
# 697     happi tri make wipe sensit skin make wipe good...
# 698     super easi use gym bag take makeup work good j...
# 699                               man favourit love smell
# 700     happi tri make wipe sensit skin make wipe good...
# 701     absolut love tan tri mani gradual moisteris ta...
# 702        live jar never goe date thing would take emigr
# 703     tub never last long hous delici especi littl c...
# 704                 absolut delici strang kid fan definit
# 705     eas use obviou advantag cloth come smell great...
# 706                 perfect stay moist packet instead dri
# 707     glad tri wipe search right one month micellar ...
# 708     love use micellar water clean skin makeup mice...
# 709     receiv today oh god great took make easili wip...
# 710     blemish prone skin use good qualiti face wash ...
# 711     like product use made face feel refresh good p...
# 712     use got keep skin quit clean strong smell alco...
# 713     one afford yet effect facial wash ever tri lea...
# 714                                 smell realli pleasant
# 715                           whole famili love ice cream
# 716     use got keep skin quit clean strong smell alco...
# 717     absolut nutrit whatsoev even feel like your ea...
# 718     use chicken mushroom pie filler thought would ...
# 719                                      love smellllllll
# 720     alway fan micellar water year saw simpl creat ...
# 721     nice wipe take whole make beed scrib face hurt...
# 722     gentl skin feel like water even get eye remov ...
# 723     happi wipe use wipe remov make cleans face wip...
# 724     foundat realli love light smooth easi appli la...
# 725     wash work well remov make eas realli gentl ski...
# 726     absolutelli love simpl product one particular ...
# 727     found face wash kind skin normal skin feel dri...
# 728     start use day ago notic big differ skin break ...
# 729     use last day facial wash great get excess make...
# 730     consciou put face sensit skin simpl product fa...
# 731                         old favourit never disappoint
# 732     revolt tast noth like real vanilla ice cream a...
# 733     ice cream creami delici chocol right bottom co...
# 734     happi wipe use wipe remov make cleans face wip...
# 735                                        usual standard
# 736     use condition year other often comment take wa...
# 737                                thankyou thought would
# 738     product great got month ago mayb help hydrat s...
# 739     wow amaz product differ skin unbeliev definit ...
# 740     love wipe use long rememb take makeup even wat...
# 741     excel wipe perfect sensit skin remov make make...
# 742     brilliant take away make sin burn face brillia...
# 743     bought facial wipe week ago packag pretti appe...
# 744     skin feel fresh use product skin feel soft ref...
# 745     use face wash year love realli gentl great sen...
# 746     consciou put face sensit skin simpl product fa...
# 747     start use day ago notic big differ skin break ...
# 748     look bodi wash leav skin dri thought pay money...
# 749     use face wash year love realli gentl great sen...
# 750     bought facial wipe week ago packag pretti appe...
# 751     brilliant take away make sin burn face brillia...
# 752     excel wipe perfect sensit skin remov make make...
# 753     love wipe use long rememb take makeup even wat...
# 754                                                 great
# 755                    good qualiti easi use job bob uncl
# 756     great smell great valu money would recommend s...
# 757                                                  good
# 758               good product leav nice smell irrit skin
# 759             simpl wipe qualiti significantli inferior
# 760                           tast great spici fear might
# 761     bought simpl wipe month ago love scent well cl...
# 762     bought coupl week ago notic sinc use skin beco...
# 763     bought wipe help clean face take make end nigh...
# 764     purchas wipe love simpl product smell absolut ...
# 765     cautiou first use wipe suffer sensit skin ofte...
# 766     tri fairli dri swatch quit conceal hand took f...
# 767     make skin feel soft clean use much better use ...
# 768     excel product left skin feel clean healthi gre...
# 769     normal oili skin use facial wash week realli s...
# 770     use long pleas overpow smell tight leav face o...
# 771     use face felt love soft cool felt refresh read...
# 772     use face wash last coupl day morn even part cl...
# 773     use cleanser twice day combin skin realli effe...
# 774     use face wash day found skin feel softer touch...
# 775     amaz product would highli recommend buy make s...
# 776     like face wash gentl skin left skin feel love ...
# 777     usual go high street product spent mani year d...
# 778     use product leav skin feel soft use everi day ...
# 779     use product week good skin cleanser seem dri s...
# 780     wipe love fragranc ok job take makeup howev we...
# 781     tri wipe instead usual one last week remov mak...
# 782     reciev wipe coupl day ago havent stop use sinc...
# 783     went away weekend decid use wet wipe think ama...
# 784     reviv product week ago usual use complet diffe...
# 785     nice product colour packag smell nice took mak...
# 786     simpl micellar wipe limit addit littl mix wipe...
# 787     use comfort sunshini day also smell amaz seen ...
# 788                                                  love
# 789     excel product left skin feel clean healthi gre...
# 790     suppos effect remov trace makeup gentl sensit ...
# 791     got around week ago tri usual morn routin real...
# 792     toner great skin alcohol free kind skin love u...
# 793     love toner use everi day sinc get definit buy ...
# 794     happi result product kind skin left skin feel ...
# 795     sooth facial toner love product remov residu l...
# 796     happi receiv product work well skin made spot ...
# 797     quit dri skin face toner help dryness felt dri...
# 798     best thing tri skin feel smooth refresh love b...
# 799     gentl skin make feel smooth soft make skin fee...
# 800     alway fan simpl product let brand gentl sensit...
# 801     realli impress toner tri mani past agre sensit...
# 802     im glad went back toner id use micellar water ...
# 803     bought wipe help clean face take make end nigh...
# 804     nice product colour packag smell nice took mak...
# 805     went away weekend decid use wet wipe think ama...
# 806     reviv product week ago usual use complet diffe...
# 807     tri wipe instead usual one last week remov mak...
# 808     love dove soap bar liquid soap amaz lather gre...
# 809     love bodi wash dove line favourit one realli l...
# 810     big fan dove doesnt much wow factor feel clean...
# 811     skin soft one wash stuff crazi like oili dri e...
# 812     use bodi wash recent work great skin moistur p...
# 813     love bodi soap like appli lotion shower realli...
# 814     moistur pretti scent well keep skin moistur da...
# 815     pretti good bodi wash cost friendli plu get jo...
# 816     buy n month n alway come back also clear white...
# 817                   lot better wet roll on spray deodor
# 818                             love similar luxuri scent
# 819                              actual work streak littl
# 820                        rich tasti beefi love put stew
# 821               tast noth shame use buy noth els anymor
# 822     face wash left face feel realli clean fresh ea...
# 823     realli great product impress far effect feel l...
# 824     love simpl product combin skin simpl product n...
# 825     love face wash like simpl product gentl skin c...
# 826     fine exactli say tin love free perfum paragon ...
# ...
# 1443    household normal use comfort howev use fresh s...
# 1444                                                 love
# 1445    list pack concentr fabric soften although rece...
# 1446    kid spend whole week without pot noodl favouri...
# 1447    love scent fresh flower fushia realli make goo...
# 1448    shop bought much expens l paid unless special ...
# 1449    effici effect nice fragranc best wash product ...
# 1450    wild eye enthusiast ask rate free magnum part ...
# 1451    use soften forev colour chang smell nice use u...
# 1452    say gluten free use one beef casserol spent ne...
# 1453    one first cream handwash could cheaper nice fr...
# 1454    use product face includ make skin feel soft sm...
# 1455    bought first time coupl week ago smell amaz fr...
# 1456    chang colour perfum product use condition year...
# 1457    buy veg stock cube big batch week bought stron...
# 1458                          great shampoo use wash hair
# 1459              incred servic bargain price thank simpl
# 1460    pack bottl laundri condition realli nice scent...
# 1461    know go get comfort regard feel smell post was...
# 1462    realli like scent overpow pleasant leav cloth ...
# 1463    good bundl product realli good dealt post holi...
# 1464    use wash cloth grandchildren excema one grandc...
# 1465                                      good bulk price
# 1466                                                 good
# 1467        son love product would recommend especi youth
# 1468                                     highli recommend
# 1469                                                 good
# 1470    bottl smaller lighter touch stiff hand find mu...
# 1471                                      amaz valu money
# 1472                        disappoint littl goe long way
# 1473                                                   ok
# 1474    use condition smell intens tri one amazon good...
# 1475        much cheaper shop work realli well nice scent
# 1476                        great product great price buy
# 1477                                           great valu
# 1478         great size keep close hand big like size get
# 1479    ml bottl give wash load fuchsia passion fabric...
# 1480    got deal amaz valu money pack enough wash bott...
# 1481                                              impress
# 1482                          fantast valu love scent buy
# 1483    clearli latest product variat comfort address ...
# 1484    usual use secret best countri mile mani mani a...
# 1485                                 anoth bathroom shelf
# 1486                                                 valu
# 1487      great conveni product much easier powder liquid
# 1488                             great offer work bag buy
# 1489    bought think got bargain wash howev disappoint...
# 1490    outer layer cover liquid becom sticki gel stic...
# 1491                                                 nice
# 1492                               get non bio great valu
# 1493                                     great valu money
# 1494    great price number wash get ad bonu carri heav...
# 1495    excel item use time great deliveri servic valu...
# 1496    superb kit persil non bio great use cloth real...
# 1497                        brilliant product love persia
# 1498    larg amount laundri yesterday immedi impress s...
# 1499                 great valu money wash smell love use
# 1500                                           love smell
# 1501                                                 good
# 1502                good price carri heavi item home shop
# 1503                             great item bargain price
# 1504         excel valu money last long better deodor use
# 1505                  great valu money would buy use wash
# 1506                         fab deal day go deodor usual
# 1507                                           wash cloth
# 1508    mistak littl bottl think worth money often off...
# 1509                                           good price
# 1510                         happi order arriv day promis
# 1511    great lot effort made reduc plastic need produ...
# 1512                                        great product
# 1513    fabric condition leav cloth soft also smell be...
# 1514                      leav nice smell cloth feel soft
# 1515                                           great valu
# 1516    storag alway better buy bigger volum keep big ...
# 1517    use brand forev love way never upset skin espe...
# 1518    order everi month good valu alway arriv time f...
# 1519                                     well worth money
# 1520                                      great smell job
# 1521    ask like review comfort intens fabric conditio...
# 1522                            shampoo best bargain also
# 1523         love smell deodor even though meant men wear
# 1524                                                 good
# 1525    love smell wash smell lush smell room cloth pu...
# 1526                                 like flavour use eat
# 1527                            good valu money would buy
# 1528                                                 good
# 1529                 slight scent keep go hour mark cloth
# 1530                             take month finish econom
# 1531                                     nice smell cloth
# 1532    smell fresh overpow handi buy bulk great price...
# 1533    seem like good deal use whole bottl fill bottl...
# 1534                     wonder scent keep feel fresh day
# 1535                                            long last
# 1536                         excel product work amazingli
# 1537    complain favourit smell good second time buy bulk
# 1538                                               hunger
# 1539    ultra concentr use much half cap full fine sce...
# 1540    love soften found bargain buy despit struggl s...
# 1541                           smell nice alway wake morn
# 1542                                                 love
# 1543                                                excel
# 1544                      conveni smell great soft fluffi
# 1545                               let know back offer pl
# 1546           cheap purchas bulk smell fantast last long
# 1547                                valu money smell love
# 1548    els say fantast valu money last month wash loa...
# 1549    love smell need use half cap full load soft fr...
# 1550    set sensit wash soap perfectli good clean well...
# 1551    hype attach scent fabric condition someth fami...
# 1552    smell gorgeou even dri tumbl great valu money ...
# 1553    gentl skin kind version within persil comfort ...
# 1554                                  good buy smell lush
# 1555    use persil non bio mani year chang brand speci...
# 1556    regularli use comfort intens condition fuscia ...
# 1557    although biolog deterg gener effect non bio ve...
# 1558    laundri set excel valu like smell persil reall...
# 1559                           great money save subscript
# 1560    current price work p per wash consid price lab...
# 1561    bulk buy intens version seem way get true valu...
# 1562            easi conveni use leav laundri fresh clean
# 1563    averag good l oreal half price ok noth special...
# 1564    sure live hype comfort clearli lead brand mark...
# 1565    big babi still realli sensit skin son also sen...
# 1566    one favourit alway feel like stop get shop nor...
# 1567    tradit comfort love fresh fragranc alway use c...
# 1568                                          great thank
# 1569                                       alway use wash
# 1570    clearli latest product variat comfort address ...
# 1571                                                 good
# 1572                        great valu money love product
# 1573    love stuff long last smell gentl skin dog bed ...
# 1574          three pack lynx shower gel decent larg size
# 1575    eat marmit nearli year alway gram jar cupboard...
# 1576             nice bargain make hair smell love smooth
# 1577    comfort alway go brand fabric soften come acro...
# 1578                                         good product
# 1579    x ml comfort intens laundri condition liquid f...
# 1580                                                 good
# 1581                                                thank
# 1582                                           good price
# 1583                                               expect
# 1584                                         receiv damag
# 1585                              got fake thin see smell
# 1586    bit worri product call intens might leav overp...
# 1587    rd time order shampoo smell good content bottl...
# 1588    current sell price compar supermarket product ...
# 1589                             bare get wash valu money
# 1590    although bottl ml condition concentr use half ...
# 1591                                         good qualiti
# 1592    sent g pop noodl instead advertis g pop noodl ...
# 1593                                  keep dri smell good
# 1594                                           good price
# 1595                                           great valu
# 1596             love smell overpow last week machin wear
# 1597                                                 love
# 1598    use separ condition year wash product day seem...
# 1599                                            work well
# 1600                               great valu plenti wash
# 1601    tradit scent fabric condit expert comfort pack...
# 1602    comfort intens nice fresh fragranc although us...
# 1603    love product retain qualiti one expect well kn...
# 1604    multi pack eight bottl fabric soften typic lar...
# 1605    famili sensit skin perfum base soften caus hav...
# 1606                                                 good
# 1607                    great qualiti super fast deliveri
# 1608    use use standard comfort fabric condition bran...
# 1609                             suppos smell fresh clean
# 1610                                          great smell
# 1611                                            good valu
# 1612    gorgeou smell fabul valu thing hike price boug...
# 1613    good bundl condition realli good love scent co...
# 1614                                    arriv cut lid bin
# 1615                        brilliant offer gorgeou smell
# 1616                             love product bargain buy
# 1617                                          great money
# 1618    like lot soft wash cloth seem remark pleasant ...
# 1619                                     clean clean nice
# 1620                                             love one
# 1621    purchas offer howev kind shock see small know ...
# 1622                                good purchas deliveri
# 1623              great price excel valu wish smell price
# 1624    found use two bottl found shin becom quit dri ...
# 1625    use persin non bio wash liquid time far best w...
# 1626                           bought product like bought
# 1627    best night cream ever use sensit dri skin slig...
# 1628     love product ive use long time recommend everyon
# 1629    love product part esenti bodi face hand moistu...
# 1630    love scrub actual feel though scrub bead actua...
# 1631    use deodour month longer sweat year swear cont...
# 1632    like lot kind skin use moistur lip make eye wo...
# 1633          love radox crazi iv got one find yellow one
# 1634    brought year ago love went get find happi find...
# 1635    vaselin one product mani use origin scent non ...
# 1636    great exfoli properti fluff end everywher wear...
# 1637    bought recent love smell make face feel clean ...
# 1638    oh say use everyday part bodi moistur makeup r...
# 1639    love vaselin soft skin feel love fact product ...
# 1640    chronic dri lip think flaki dri tri mani varie...
# 1641    alway great versatil use lip elbow knee heel e...
# 1642    amaz cant rate enough got gift stop smell scen...
# 1643    use use time howev sinc newer one came round d...
# 1644    tri shampoo alway use l oreal elviv colour hai...
# 1645    amaz cant rate enough got gift stop smell scen...
# 1646    luxuri cream love smell gave bodi love glow so...
# 1647    impress tan lotion sticki could bear feel stic...
# 1648    great exfoli properti fluff end everywher wear...
# 1649    drink tea long time latest deliveri tast diffe...
# 1650    bought friend use love smell never normal use ...
# 1651    one best shower soap ever use loveliest smell ...
# 1652    time favourit soften never smelt anyth nice la...
# 1653    buy veg stock cube big batch week bought stron...
# 1654                   love use year smell love start end
# 1655    one favourit scent howev recent notic conditio...
# 1656    normal buy persil colour powder seem unavail d...
# 1657    use soften forev colour chang smell nice use h...
# 1658                     great ever alway soup best anyon
# 1659    sinc discov smell never chang got shop week di...
# 1660           bring bk surf gem good vaul money easi use
# 1661    wife love good shower gel one say leav skin su...
# 1662                                      bought daughter
# 1663    feel like dilut peopl prefer mild scent love f...
# 1664               use lot realli good surprisingli cheap
# 1665                                                 good
# 1666                            say protect hair blow dri
# 1667                worth money excel product well packag
# 1668                                    realli good price
# 1669    fine littl process hair long problem extra bod...
# 1670     oddli enough felt like unblock gradual day pleas
# 1671               realli good size make cloth smell nice
# 1672                                           excel valu
# 1673                                             nice say
# 1674                                          smell great
# 1675                              spell nice cleaner good
# 1676                                                great
# 1677                            last year pack great valu
# 1678    smell nice minut work use sever past week bo n...
# 1679                                           smell love
# 1680    ad recent amazon pantri order good offer price...
# 1681                  well love whole famili henc purchas
# 1682                normal complain look like cut lid bin
# 1683                              love product great hair
# 1684                         love stuff liter clean anyth
# 1685         bought prime food packag good hellmann alway
# 1686                    pack good l actual consum product
# 1687                                     shine well clean
# 1688                                   would wash without
# 1689                          smell realli nice would buy
# 1690                                              describ
# 1691    nice scent larg bottl seem last base smallest ...
# 1692                                        great product
# 1693                                           said bottl
# 1694                            alway use one price great
# 1695    might suitabl sensit skin one keep scent long ...
# 1696                                         good product
# 1697                                          famili like
# 1698    use spray everi time dri hair protect beauti h...
# 1699             pleas aroma launder cloth ect valu money
# 1700                                            tast fine
# 1701                        melt easili sauc overli salti
# 1702    disappoint size seem small ice cream funni tex...
# 1703                  would good point cif test anim nope
# 1704    quit happili buy instead usual cornetto flavou...
# 1705    grandchildren love lolli unfortun prefer green...
# 1706                         sinc real thing welcom treat
# 1707    love shower gel great sensit skin pleasant fra...
# 1708    im coeliac intoler cow milk huge sweet tooth i...
# 1709    dissapoint capsul previou version ultra two co...
# 1710     find wipe get make easili far superior wipe alon
# 1711    great tast gluten free vegan palm oil highli r...
# 1712    excit purchas react usual dairi brand cone lov...
# 1713    amaz like origin cornetto vegan im realli impress
# 1714    whole famili love bovril use daili toast morn ...
# 1715    content bottl love howev tri get squeezi bottl...
# 1716                    tast great cannot cant tell vegan
# 1717    realli pleas vegan cornetto last close dairi v...
# Name: review_text, dtype: object

# %%
#CHECK RARE WORDS
r = pd.Series(' '.join(review_data['review_text']).split()).value_counts()[-10:]
print("RARE WORDS:")
print(r)
# Out:
# RARE WORDS:
# accident     1
# chuck        1
# emigr        1
# salt         1
# mushroom     1
# fli          1
# cult         1
# revitalis    1
# advantag     1
# tendon       1
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

def generate_horizontal_word_clouds(data, text_column, positive_threshold=4, negative_threshold=2):
    """
    Generate and display word clouds for positive and negative reviews.
    
    Parameters:
    - data: DataFrame containing the reviews
    - text_column: The column name containing the review texts
    - positive_threshold: Rating threshold for positive reviews
    - negative_threshold: Rating threshold for negative reviews
    """
    
    # Generate Word Cloud for Positive Reviews
    positive_reviews = data[data['review_rating'] >= positive_threshold][text_column].str.cat(sep=' ')
    wordcloud_pos = WordCloud(width=400, height=400, background_color='white', max_words=200, collocations=True,
                              colormap='viridis', max_font_size=100, min_font_size=10).generate(positive_reviews)

    # Generate Word Cloud for Negative Reviews
    negative_reviews = data[data['review_rating'] <= negative_threshold][text_column].str.cat(sep=' ')
    wordcloud_neg = WordCloud(width=400, height=400, background_color='white', max_words=50, collocations=False,
                              colormap='plasma', max_font_size=100, min_font_size=10).generate(negative_reviews)

    # Display Word Clouds Horizontally
    plt.figure(figsize=(10, 5))  # Increased width for more spacing

    # Positive Word Cloud
    plt.subplot(1, 2, 1)
    plt.imshow(wordcloud_pos, interpolation='bilinear')
    plt.axis('off')
    plt.title('Word Cloud for Positive Reviews', pad=20, fontsize=16)  # Set title font size

    # Negative Word Cloud
    plt.subplot(1, 2, 2)
    plt.imshow(wordcloud_neg, interpolation='bilinear')
    plt.axis('off')
    plt.title('Word Cloud for Negative Reviews', pad=20, fontsize=16)  # Set title font size

    # Adjust spacing between charts
    plt.subplots_adjust(wspace=0.5)  # Adjust this value for more or less space

    plt.tight_layout()
    plt.show()

# %%
# Call the function
generate_horizontal_word_clouds(review_data, 'review_text')

# %% [markdown]
# >After analyzing the review data, we found that the most common words used in the reviews tend to be positive, indicating that customers generally have a good experience with the products.
#
# 1. Common Words: We removed some of the most frequent words that didn't add much meaning to the reviews. After doing this, we identified the top 10 words that reflect customer sentiment.
#
# 2. Positive Sentiment: The overall tone of the reviews is positive, which is a good sign for the products being analyzed.
#
# 3. Limitation: It’s important to note that our dataset lacks negative reviews. This could lead to challenges when trying to determine whether a review is "fake" or "real" based solely on the sentiment, as we don't have enough examples of negative feedback to compare agains

# %%
# # Sentiment Analysis: Count of Positive and Negative Reviews
positive_count = review_data[review_data['review_rating'] >= 4].shape[0]
negative_count = review_data[review_data['review_rating'] <= 2].shape[0]

plt.figure(figsize=(8, 5))
sns.barplot(x=['Positive', 'Negative'], y=[positive_count, negative_count], palette='Set2')
plt.title('Count of Positive and Negative Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Count of Reviews')
plt.show()

# %%
review_data['review_text'].apply(word_tokenize).head()
# Out:
# 0    [get, older, know, like, suitabl, bodi, like, ...
# 1    [three, gigant, marmit, jar, last, probabl, wh...
# 2                                              [excel]
# 3                    [great, flavour, top, slow, cook]
# 4                                                [say]
# Name: review_text, dtype: object

# %%
#SAVING UPDATED DATAFRAME AS .csv FILE
review_data.to_csv('C:/Data_Science/Mini Project/Capston Project/Capston_IOD_Project/DATABASE files/cleaned_data.csv')
